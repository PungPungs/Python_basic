# %% [markdown]
# # 데이터 전처리

# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv("./data/Clean_Dataset.csv")
df.drop(df.columns[0],axis=1, inplace=True)

# %%
random.seed(2023)
np.random.seed(2023)

df_na = df.copy()
for i in range(5000):
    df_na.iloc[random.randint(0,300152),random.randint(0,10)]=np.nan

df_na.iloc[1] = np.nan
df_na.iloc[3] = np.nan

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299685 non-null  object
#  1   flight            299689 non-null  object
#  2   source_city       299681 non-null  object
#  3   departure_time    299723 non-null  object
#  4   stops             299666 non-null  object
#  5   arrival_time      299698 non-null  object
#  6   destination_city  299670 non-null  object
#  7   class             299715 non-null  object
#  8   duration          299703 non-null  float64
#  9   days_left         299723 non-null  float64
#  10  price             299714 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 25.2+ MB

# %%
df_na.isnull().sum(axis=0)
# Out:
# airline             468
# flight              464
# source_city         472
# departure_time      430
# stops               487
# arrival_time        455
# destination_city    483
# class               438
# duration            450
# days_left           430
# price               439
# dtype: int64

# %%
df_na_origin = df_na.copy()

# %%
# 기본적으로 parameter = any 설정되어 있어 결측치 행 전체 삭제, all로 바꾸면 모든 행이 Nan이면 삭제
df_na = df_na.dropna()
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295192 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           295192 non-null  object
#  1   flight            295192 non-null  object
#  2   source_city       295192 non-null  object
#  3   departure_time    295192 non-null  object
#  4   stops             295192 non-null  object
#  5   arrival_time      295192 non-null  object
#  6   destination_city  295192 non-null  object
#  7   class             295192 non-null  object
#  8   duration          295192 non-null  float64
#  9   days_left         295192 non-null  float64
#  10  price             295192 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 27.0+ MB

# %%
df_na=df_na_origin.copy()
df_na.dropna(how="all",inplace=True)

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300151 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299685 non-null  object
#  1   flight            299689 non-null  object
#  2   source_city       299681 non-null  object
#  3   departure_time    299723 non-null  object
#  4   stops             299666 non-null  object
#  5   arrival_time      299698 non-null  object
#  6   destination_city  299670 non-null  object
#  7   class             299715 non-null  object
#  8   duration          299703 non-null  float64
#  9   days_left         299723 non-null  float64
#  10  price             299714 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 27.5+ MB

# %%
df_na.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6   Vistara   UK-927       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left   price
# 0           Mumbai  Economy      2.17        1.0  5953.0
# 2           Mumbai  Economy      2.17        1.0  5956.0
# 4           Mumbai  Economy      2.33        1.0  5955.0
# 5           Mumbai  Economy      2.33        1.0  5955.0
# 6           Mumbai  Economy      2.08        1.0  6060.0

# %%
df_na = df_na_origin.copy()

df_na.drop(['stops','flight'],axis=1, inplace=True)
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299685 non-null  object
#  1   source_city       299681 non-null  object
#  2   departure_time    299723 non-null  object
#  3   arrival_time      299698 non-null  object
#  4   destination_city  299670 non-null  object
#  5   class             299715 non-null  object
#  6   duration          299703 non-null  float64
#  7   days_left         299723 non-null  float64
#  8   price             299714 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 20.6+ MB

# %%
df_na.dropna(inplace=True)
df_na.info()
# 컬럼을 삭제하기 전 보다 데이터 수가 많다. 컬럼 삭제가 최선은 아니지만 결측치가 많으면 고려할만하다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 296124 entries, 0 to 300152
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           296124 non-null  object
#  1   source_city       296124 non-null  object
#  2   departure_time    296124 non-null  object
#  3   arrival_time      296124 non-null  object
#  4   destination_city  296124 non-null  object
#  5   class             296124 non-null  object
#  6   duration          296124 non-null  float64
#  7   days_left         296124 non-null  float64
#  8   price             296124 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 22.6+ MB

# %%
df_na = df_na_origin.copy()
df_na.fillna(df_na.mean(numeric_only=True),inplace=True)

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299685 non-null  object
#  1   flight            299689 non-null  object
#  2   source_city       299681 non-null  object
#  3   departure_time    299723 non-null  object
#  4   stops             299666 non-null  object
#  5   arrival_time      299698 non-null  object
#  6   destination_city  299670 non-null  object
#  7   class             299715 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  float64
#  10  price             300153 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 25.2+ MB

# %%
df_na.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       NaN      NaN         NaN            NaN   NaN            NaN
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3       NaN      NaN         NaN            NaN   NaN            NaN
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class   duration  days_left         price
# 0           Mumbai  Economy   2.170000   1.000000   5953.000000
# 1              NaN      NaN  12.220991  26.006369  20888.967105
# 2           Mumbai  Economy   2.170000   1.000000   5956.000000
# 3              NaN      NaN  12.220991  26.006369  20888.967105
# 4           Mumbai  Economy   2.330000   1.000000   5955.000000

# %%
df_na.fillna(method='bfill',inplace=True) # pad, ffill : 이전인덱스값을 사용하여 결측치를 채움, backfill,bfill 다음 인덱스값을 사용하여 결측치를 채움
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  float64
#  10  price             300153 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 25.2+ MB
# C:\Users\keyha\AppData\Local\Temp\ipykernel_15876\416050411.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_na.fillna(method='bfill',inplace=True) # pad, ffill : 이전인덱스값을 사용하여 결측치를 채움, backfill,bfill 다음 인덱스값을 사용하여 결측치를 채움

# %%
df_na.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-963       Delhi        Morning  zero        Morning
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class   duration  days_left         price
# 0           Mumbai  Economy   2.170000   1.000000   5953.000000
# 1           Mumbai  Economy  12.220991  26.006369  20888.967105
# 2           Mumbai  Economy   2.170000   1.000000   5956.000000
# 3           Mumbai  Economy  12.220991  26.006369  20888.967105
# 4           Mumbai  Economy   2.330000   1.000000   5955.000000

# %% [markdown]
# Z-Score(Z-Distibution)
# - 어떤 값의 평균이 표준편차에서 얼마나 떨어져있는지를 알려줌
# - 이상치 탐지, 정규분포 해석에 사용
# - 평균적으로 95% 신뢰수준을 사용
# $$
# Z = \frac{x_i - mean(X)}{\sigma}
# $$

# %%
df[(abs((df['price']-df['price'].mean())/df['price'].std())) > 1.96]
# Out:
#         airline  flight source_city departure_time stops arrival_time  \
# 206691  Vistara  UK-809       Delhi        Evening   one      Morning
# 206692  Vistara  UK-813       Delhi        Evening   one      Morning
# 206693  Vistara  UK-809       Delhi        Evening   one        Night
# 206694  Vistara  UK-809       Delhi        Evening   one        Night
# 206695  Vistara  UK-813       Delhi        Evening   one        Night
# ...         ...     ...         ...            ...   ...          ...
# 300148  Vistara  UK-822     Chennai        Morning   one      Evening
# 300149  Vistara  UK-826     Chennai      Afternoon   one        Night
# 300150  Vistara  UK-832     Chennai  Early_Morning   one        Night
# 300151  Vistara  UK-828     Chennai  Early_Morning   one      Evening
# 300152  Vistara  UK-822     Chennai        Morning   one      Evening
#
#        destination_city     class  duration  days_left  price
# 206691           Mumbai  Business     12.42          1  74640
# 206692           Mumbai  Business     14.67          1  74640
# 206693           Mumbai  Business     24.42          1  74640
# 206694           Mumbai  Business     26.00          1  74640
# 206695           Mumbai  Business     26.67          1  74640
# ...                 ...       ...       ...        ...    ...
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585
#
# [12493 rows x 11 columns]

# %%
# IRQ 기준 이상치 확인하는 함수
def findOutliers(x,colum):
    q1 = x[colum].quantile(0.25)
    q3 = x[colum].quantile(0.75)

    iqr = q3 - q1
    # 1.5배의 irq
    iqr = 1.5 * iqr
    
    y = x[(x[colum] > (q3 + iqr)) | (x[colum] < (q1 - iqr))]

    return len(y)


print("price IQR Outliers : ",findOutliers(df,'price'))
print("duration IQR Outliers : ", findOutliers(df,'duration'))
print("days_left IQR Outliers : ", findOutliers(df, 'days_left'))
# Out:
# price IQR Outliers :  123
# duration IQR Outliers :  2110
# days_left IQR Outliers :  0

# %%
import matplotlib.pyplot as plt

# %%
# 새로운 그림을 그림
plt.figure()

# 첫번쨰 서브플랏 : 1행 5열로 나눈 영역에서 첫 번째 영역
plt.subplot(151)
df[['duration']].boxplot()
plt.ylabel("Time")


# ex 153 -> 1행 5열 3번째 영역
plt.subplot(153)
df[['days_left']].boxplot()
plt.ylabel('days')

plt.subplot(155)
df[['price']].boxplot()
plt.ylabel("price")
plt.show()

# %%
df_origin = df.copy()

outlier = df[(abs((df['price']-df['price'].mean())/df['price'].std())) > 1.96].index

clean_df = df.drop(outlier)

# %%
plt.figure(figsize=(4,5))
clean_df[['price']].boxplot()
plt.show()

# %%
def changeOutliers(x,column):

    q1 = x[column].quantile(0.25)
    q3 = x[column].quantile(0.75)

    iqr = q3 - q1

    iqr = 1.5 * iqr

    Min = (q1 - iqr)
    Max = (q3 + iqr)

    x.loc[(x[column] > Max),column] = Max
    x.loc[(x[column] < Min),column] = Min

    return(x)


clean_df = changeOutliers(df,'price')
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
clean_df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# $$하한(Min)=Q1−1.5×IQR$$
#
#
# $$상한(Max)=𝑄3+1.5×IQR$$

# %% [markdown]
# 구간화(binning)
# - 구간화는 연속형 데이터를 특정 구간으로 나는 것을 의미
# - 동일 구간, 동일 개수 구간화가 있음

# %%
df[['duration']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 1 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   duration  300153 non-null  float64
# dtypes: float64(1)
# memory usage: 2.3 MB

# %%
df['distance'] = pd.cut(df['duration'],bins = [0,5,10,df['duration'].max()], labels=['short','medium','long'])
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price distance
# 0           Mumbai  Economy      2.17          1   5953    short
# 1           Mumbai  Economy      2.33          1   5953    short
# 2           Mumbai  Economy      2.17          1   5956    short
# 3           Mumbai  Economy      2.25          1   5955    short
# 4           Mumbai  Economy      2.33          1   5955    short

# %%
# 장거리 비행이 더 많음
df['distance'].value_counts()
# Out:
# distance
# long      169879
# medium     84761
# short      45513
# Name: count, dtype: int64

# %%
df['price_rate'] = pd.qcut(df['price'],4,labels=['cheap','normal','expensive','too expensive'])
df.head
# Out:
# <bound method NDFrame.head of          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price distance  \
# 0                Mumbai   Economy      2.17          1   5953    short
# 1                Mumbai   Economy      2.33          1   5953    short
# 2                Mumbai   Economy      2.17          1   5956    short
# 3                Mumbai   Economy      2.25          1   5955    short
# 4                Mumbai   Economy      2.33          1   5955    short
# ...                 ...       ...       ...        ...    ...      ...
# 300148        Hyderabad  Business     10.08         49  69265     long
# 300149        Hyderabad  Business     10.42         49  77105     long
# 300150        Hyderabad  Business     13.83         49  79099     long
# 300151        Hyderabad  Business     10.00         49  81585   medium
# 300152        Hyderabad  Business     10.08         49  81585     long
#
#            price_rate
# 0              normal
# 1              normal
# 2              normal
# 3              normal
# 4              normal
# ...               ...
# 300148  too expensive
# 300149  too expensive
# 300150  too expensive
# 300151  too expensive
# 300152  too expensive
#
# [300153 rows x 13 columns]>

# %%
df['price_rate'].value_counts()
# Out:
# price_rate
# expensive        75584
# normal           75117
# cheap            75073
# too expensive    74379
# Name: count, dtype: int64

# %%
df = pd.read_csv("./data/Clean_Dataset.csv")
df_origin = df.copy()

# %%
df["label_encoding"] = pd.factorize(df["airline"])[0].reshape(-1,1)
df.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price  \
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955
#
#    label_encoding
# 0               0
# 1               0
# 2               1
# 3               2
# 4               2

# %%
df.drop(df.columns[0],axis=1,inplace=True)
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  label_encoding
# 0           Mumbai  Economy      2.17          1   5953               0
# 1           Mumbai  Economy      2.33          1   5953               0
# 2           Mumbai  Economy      2.17          1   5956               1
# 3           Mumbai  Economy      2.25          1   5955               2
# 4           Mumbai  Economy      2.33          1   5955               2

# %%
print(df['airline'].value_counts())
print(df['label_encoding'].value_counts())
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64
# label_encoding
# 2    127859
# 5     80892
# 4     43120
# 3     23173
# 1     16098
# 0      9011
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['airline_label_encoding']=le.fit_transform(df['airline'])
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  label_encoding  \
# 0           Mumbai  Economy      2.17          1   5953               0
# 1           Mumbai  Economy      2.33          1   5953               0
# 2           Mumbai  Economy      2.17          1   5956               1
# 3           Mumbai  Economy      2.25          1   5955               2
# 4           Mumbai  Economy      2.33          1   5955               2
#
#    airline_label_encoding
# 0                       4
# 1                       4
# 2                       0
# 3                       5
# 4                       5

# %%
print(df['airline'].value_counts())
print(df['airline_label_encoding'].value_counts())
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64
# airline_label_encoding
# 5    127859
# 1     80892
# 3     43120
# 2     23173
# 0     16098
# 4      9011
# Name: count, dtype: int64

# %%
le.inverse_transform(df['airline_label_encoding']).reshape(-1,1) # -1은 자동으로 계산?
# Out:
# array([['SpiceJet'],
#        ['SpiceJet'],
#        ['AirAsia'],
#        ...,
#        ['Vistara'],
#        ['Vistara'],
#        ['Vistara']], dtype=object)

# %%
df = df_origin.copy()
# class 를 원핫인코딩
pd.get_dummies(df, columns=['class'])
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city  duration  days_left  price  \
# 0               Night           Mumbai      2.17          1   5953
# 1             Morning           Mumbai      2.33          1   5953
# 2       Early_Morning           Mumbai      2.17          1   5956
# 3           Afternoon           Mumbai      2.25          1   5955
# 4             Morning           Mumbai      2.33          1   5955
# ...               ...              ...       ...        ...    ...
# 300148        Evening        Hyderabad     10.08         49  69265
# 300149          Night        Hyderabad     10.42         49  77105
# 300150          Night        Hyderabad     13.83         49  79099
# 300151        Evening        Hyderabad     10.00         49  81585
# 300152        Evening        Hyderabad     10.08         49  81585
#
#         class_Business  class_Economy
# 0                False           True
# 1                False           True
# 2                False           True
# 3                False           True
# 4                False           True
# ...                ...            ...
# 300148            True          False
# 300149            True          False
# 300150            True          False
# 300151            True          False
# 300152            True          False
#
# [300153 rows x 13 columns]

# %%
df_origin.drop(df_origin.columns[0],axis=1,inplace=True)

# %%
df = df_origin.copy()
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
from sklearn.preprocessing import OneHotEncoder

oh = OneHotEncoder()
encoder = oh.fit_transform(df['class'].values.reshape(-1,1)).toarray()

# %%
df_OneHot = pd.DataFrame(encoder, columns=["class" + str(oh.categories_[0][i]) for i in range(len(oh.categories_[0]))])

df1 = pd.concat([df,df_OneHot],axis=1)
df1.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  classBusiness  \
# 0           Mumbai  Economy      2.17          1   5953            0.0
# 1           Mumbai  Economy      2.33          1   5953            0.0
# 2           Mumbai  Economy      2.17          1   5956            0.0
# 3           Mumbai  Economy      2.25          1   5955            0.0
# 4           Mumbai  Economy      2.33          1   5955            0.0
#
#    classEconomy
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0

# %% [markdown]
# 수치적으로 수치가 큰 값들과 작은 값들의 크기를 맞춰주는 작업이 스케일링 이다.
# $$
# x_{std} = \frac{x_i - X_{min}}{X_{max} - X_{min}}
# $$

# %%
# min-max scaling - 극단적 이상치에 민감, 이상치 제거 필
df = df_origin.copy()
df_num = df[['duration','days_left','price']]
df_num = ((df_num - df_num.min())/(df_num.max() - df_num.min()))
df_num.head()
# Out:
#    duration  days_left     price
# 0  0.027347        0.0  0.039749
# 1  0.030612        0.0  0.039749
# 2  0.027347        0.0  0.039773
# 3  0.028980        0.0  0.039765
# 4  0.030612        0.0  0.039765

# %%
df_num.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean        0.232470       0.520932       0.162215
# std         0.146775       0.282521       0.186099
# min         0.000000       0.000000       0.000000
# 25%         0.122449       0.291667       0.030156
# 50%         0.212653       0.520833       0.051818
# 75%         0.313061       0.770833       0.339570
# max         1.000000       1.000000       1.000000

# %% [markdown]
# 표준화
# $$
# X_{norm} = \frac{(x_i - X_{mean})}{{X_{std}}}
# $$

# %%
df_num = df[['duration','days_left','price']]
df_num = (df_num - df_num.mean()) / df_num.std()
df_num.head()
df_num.describe()
# Out:
#            duration     days_left         price
# count  3.001530e+05  3.001530e+05  3.001530e+05
# mean   9.090311e-17  1.810487e-16 -1.939266e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.583847e+00 -1.843872e+00 -8.716567e-01
# 25%   -7.495861e-01 -8.114997e-01 -7.096143e-01
# 50%   -1.350141e-01 -3.503362e-04 -5.932152e-01
# 75%    5.490796e-01  8.845399e-01  9.530162e-01
# max    5.229282e+00  1.695689e+00  4.501823e+00

# %%
df.drop(['duration','days_left','price'],axis=1)

df = pd.concat([df,df_num],axis=1)
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  duration  days_left  \
# 0           Mumbai  Economy      2.17          1   5953 -1.397528  -1.843872
# 1           Mumbai  Economy      2.33          1   5953 -1.375282  -1.843872
# 2           Mumbai  Economy      2.17          1   5956 -1.397528  -1.843872
# 3           Mumbai  Economy      2.25          1   5955 -1.386405  -1.843872
# 4           Mumbai  Economy      2.33          1   5955 -1.375282  -1.843872
#
#       price
# 0 -0.658067
# 1 -0.658067
# 2 -0.657935
# 3 -0.657979
# 4 -0.657979

# %%
def df_split_flight(flight):
    manufacture = flight.split("-")[0]
    model = flight.split("-")[1]
    return manufacture, model

df['manufacture'],df['model_num'] = zip(*df['flight'].apply(lambda x : df_split_flight(x)))
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  duration  days_left  \
# 0           Mumbai  Economy      2.17          1   5953 -1.397528  -1.843872
# 1           Mumbai  Economy      2.33          1   5953 -1.375282  -1.843872
# 2           Mumbai  Economy      2.17          1   5956 -1.397528  -1.843872
# 3           Mumbai  Economy      2.25          1   5955 -1.386405  -1.843872
# 4           Mumbai  Economy      2.33          1   5955 -1.375282  -1.843872
#
#       price manufacture model_num
# 0 -0.658067          SG      8709
# 1 -0.658067          SG      8157
# 2 -0.657935          I5       764
# 3 -0.657979          UK       995
# 4 -0.657979          UK       963

# %%
df['route'] = df.apply(lambda x :(x['source_city'],x['destination_city']),axis=1)
df.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  duration  days_left  \
# 0           Mumbai  Economy      2.17          1   5953 -1.397528  -1.843872
# 1           Mumbai  Economy      2.33          1   5953 -1.375282  -1.843872
# 2           Mumbai  Economy      2.17          1   5956 -1.397528  -1.843872
# 3           Mumbai  Economy      2.25          1   5955 -1.386405  -1.843872
# 4           Mumbai  Economy      2.33          1   5955 -1.375282  -1.843872
#
#       price manufacture model_num            route
# 0 -0.658067          SG      8709  (Delhi, Mumbai)
# 1 -0.658067          SG      8157  (Delhi, Mumbai)
# 2 -0.657935          I5       764  (Delhi, Mumbai)
# 3 -0.657979          UK       995  (Delhi, Mumbai)
# 4 -0.657979          UK       963  (Delhi, Mumbai)

# %% [markdown]
# #### Recursive Feature Elimination
# - 재귀적으로 반복하여 최적의 변수를 찾는 방법
# #### Recursive Feature Elimination Cross Validation
# - RFE의 변형으로 교차검증이 추가된 방법이다. 최적의 값을 찾으면 중단한다.
# #### Univariate Feature Selection
# - 일변량 통계 테스트를 기반으로 최상의 변수를 선택.
# - 특성 검정 통계(F-value or 카이-제곱값)을 통해 평가하고 높은 점수를 가지는 특성을 선택
#
# #### 추가적인 공부 사항 : F-Value, 일변량 통계 테스트
